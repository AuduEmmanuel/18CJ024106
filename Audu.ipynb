# %%
import pandas as pd

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="2002", 
     database="milktotal"
)

print(mydb)

mycursor = mydb.cursor()

# %%
#FETCH

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="2002", 
     database="milktotal"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM milktotal.milk_total WHERE MyUnknownColumn IN ('Algeria','Angola','Benin','Botswana','Burkina Faso','Burundi','Cameroon','Cape Verde','Central African Republic','Chad','Comoros','Democratic Republic of the Congo','Djibouti','Egypt','Equatorial Guinea','Eritrea','Eswatini','Ethiopia','Gabon','Gambia','Ghana','Guinea','Guinea-Bissau','Kenya','Lesotho','Liberia','Libyan Arab Jamahiriya','Madagascar','Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda','Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia','Uganda''Zambia','Zimbabwe')"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Algeria', 'Production', 2018, 'tonnes', 3064927, 'A')
# ('Algeria', 'Production', 2017, 'tonnes', 3595595, 'A')
# ('Algeria', 'Production', 2016, 'tonnes', 3654999, 'A')
# ('Algeria', 'Production', 2015, 'tonnes', 3481644, 'A')
# ('Algeria', 'Production', 2014, 'tonnes', 4100019, 'A')
# ('Algeria', 'Production', 2013, 'tonnes', 3882603, 'A')
# ('Algeria', 'Production', 2012, 'tonnes', 3664597, 'A')
# ('Algeria', 'Production', 2011, 'tonnes', 3480704, 'A')
# ('Algeria', 'Production', 2010, 'tonnes', 3160434, 'A')
# ('Algeria', 'Production', 2009, 'tonnes', 2879903, 'A')
# ('Angola', 'Production', 2018, 'tonnes', 217567, 'A')
# ('Angola', 'Production', 2017, 'tonnes', 215953, 'A')
# ('Angola', 'Production', 2016, 'tonnes', 214989, 'A')
# ('Angola', 'Production', 2015, 'tonnes', 215482, 'A')
# ('Angola', 'Production', 2014, 'tonnes', 190000, 'A')
# ('Angola', 'Production', 2013, 'tonnes', 187000, 'A')
# ('Angola', 'Production', 2012, 'tonnes', 185500, 'A')
# ...

# %%
#MODIFY

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="2002", 
     database="milktotal"
)

mycursor = mydb.cursor()

sql = "SELECT * FROM milktotal.milk_total ORDER BY Year DESC"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Algeria', 'Production', 2018, 'tonnes', 3064927, 'A')
# ('Angola', 'Production', 2018, 'tonnes', 217567, 'A')
# ('Benin', 'Production', 2018, 'tonnes', 149277, 'A')
# ('Botswana', 'Production', 2018, 'tonnes', 303517, 'A')
# ('Burkina Faso', 'Production', 2018, 'tonnes', 330119, 'A')
# ('Burundi', 'Production', 2018, 'tonnes', 108102, 'A')
# ('Cabo Verde', 'Production', 2018, 'tonnes', 10079, 'A')
# ('Cameroon', 'Production', 2018, 'tonnes', 245327, 'A')
# ('Central African Republic', 'Production', 2018, 'tonnes', 81593, 'A')
# ('Chad', 'Production', 2018, 'tonnes', 383240, 'A')
# ('Comoros', 'Production', 2018, 'tonnes', 13406, 'A')
# ('Congo', 'Production', 2018, 'tonnes', 5116, 'A')
# ("Côte d'Ivoire", 'Production', 2018, 'tonnes', 30186, 'A')
# ('Democratic Republic of the Congo', 'Production', 2018, 'tonnes', 7293, 'A')
# ('Djibouti', 'Production', 2018, 'tonnes', 14908, 'A')
# ('Egypt', 'Production', 2018, 'tonnes', 4471275, 'A')
# ...

# %%
#MODIFY

import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="2002", 
     database="milktotal"
)


mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM milktotal.milk_total LIMIT 150")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Algeria', 'Production', 2018, 'tonnes', 3064927, 'A')
# ('Algeria', 'Production', 2017, 'tonnes', 3595595, 'A')
# ('Algeria', 'Production', 2016, 'tonnes', 3654999, 'A')
# ('Algeria', 'Production', 2015, 'tonnes', 3481644, 'A')
# ('Algeria', 'Production', 2014, 'tonnes', 4100019, 'A')
# ('Algeria', 'Production', 2013, 'tonnes', 3882603, 'A')
# ('Algeria', 'Production', 2012, 'tonnes', 3664597, 'A')
# ('Algeria', 'Production', 2011, 'tonnes', 3480704, 'A')
# ('Algeria', 'Production', 2010, 'tonnes', 3160434, 'A')
# ('Algeria', 'Production', 2009, 'tonnes', 2879903, 'A')
# ('Angola', 'Production', 2018, 'tonnes', 217567, 'A')
# ('Angola', 'Production', 2017, 'tonnes', 215953, 'A')
# ('Angola', 'Production', 2016, 'tonnes', 214989, 'A')
# ('Angola', 'Production', 2015, 'tonnes', 215482, 'A')
# ('Angola', 'Production', 2014, 'tonnes', 190000, 'A')
# ('Angola', 'Production', 2013, 'tonnes', 187000, 'A')
# ('Angola', 'Production', 2012, 'tonnes', 185500, 'A')
# ...
